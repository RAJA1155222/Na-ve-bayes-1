# %% [markdown]
# Q1. What is Bayes’ theorem?
#
# Bayes’ theorem is a fundamental rule in probability theory that relates conditional probabilities.
#
# It allows us to update the probability of a hypothesis (event) given new evidence.
#
# In practice, it’s the basis for probabilistic models such as Naive Bayes classifiers.
#
# Q2. Formula for Bayes’ theorem
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# ⋅
# 𝑃
# (
# 𝐴
# )
# 𝑃
# (
# 𝐵
# )
# P(A∣B)=
# P(B)
# P(B∣A)⋅P(A)
# 	​
#
#
# Where:
#
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# P(A∣B) → posterior probability of event A given B
#
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# P(B∣A) → likelihood of observing B if A is true
#
# 𝑃
# (
# 𝐴
# )
# P(A) → prior probability of A
#
# 𝑃
# (
# 𝐵
# )
# P(B) → marginal probability of B
#
# Q3. How is Bayes’ theorem used in practice?
#
# Medical diagnosis: Estimate probability of disease given symptoms.
#
# Spam detection: Probability an email is spam given the words it contains.
#
# Machine learning: Basis of Naive Bayes classifiers.
#
# Risk assessment & decision making: Updating beliefs with new evidence.
#
# Q4. Relationship between Bayes’ theorem and conditional probability
#
# Conditional probability:
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# P(A∣B) is the probability of A given B.
#
# Bayes’ theorem expresses conditional probability in terms of the reverse conditional probability:
#
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# ⋅
# 𝑃
# (
# 𝐴
# )
# 𝑃
# (
# 𝐵
# )
# P(A∣B)=
# P(B)
# P(B∣A)⋅P(A)
# 	​
#
#
# It allows flipping
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# P(A∣B) to
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# P(B∣A) when the latter is easier to calculate.
#
# Q5. Choosing the type of Naive Bayes classifier
#
# Common types of Naive Bayes:
#
# Type	Assumption	Use case
# GaussianNB	Features are continuous and normally distributed	Height, weight, blood pressure
# MultinomialNB	Features are counts or frequencies	Text classification, word counts
# BernoulliNB	Features are binary (0/1)	Email spam (word present/absent)
#
# Rule of thumb: Choose based on feature type.
#
# Q6. Assignment: Predicting class with Naive Bayes
#
# Dataset:
#
# Class	X1=1	X1=2	X1=3	X2=1	X2=2	X2=3	X2=4
# A	3	3	4	4	3	3	3
# B	2	2	1	2	2	2	3
#
# New instance: X1=3, X2=4
#
# Assume equal priors:
# 𝑃
# (
# 𝐴
# )
# =
# 𝑃
# (
# 𝐵
# )
# =
# 0.5
# P(A)=P(B)=0.5
#
# Use Multinomial Naive Bayes formula:
#
# 𝑃
# (
# 𝐶
# 𝑙
# 𝑎
# 𝑠
# 𝑠
# ∣
# 𝑋
# 1
# ,
# 𝑋
# 2
# )
# ∝
# 𝑃
# (
# 𝐶
# 𝑙
# 𝑎
# 𝑠
# 𝑠
# )
# ⋅
# 𝑃
# (
# 𝑋
# 1
# ∣
# 𝐶
# 𝑙
# 𝑎
# 𝑠
# 𝑠
# )
# ⋅
# 𝑃
# (
# 𝑋
# 2
# ∣
# 𝐶
# 𝑙
# 𝑎
# 𝑠
# 𝑠
# )
# P(Class∣X1,X2)∝P(Class)⋅P(X1∣Class)⋅P(X2∣Class)
# Step 1: Calculate likelihoods
#
# For Class A:
#
# Total counts for X1 in A:
# 3
# +
# 3
# +
# 4
# =
# 10
# 3+3+4=10
#
# 𝑃
# (
# 𝑋
# 1
# =
# 3
# ∣
# 𝐴
# )
# =
# 4
# /
# 10
# =
# 0.4
# P(X1=3∣A)=4/10=0.4
#
# Total counts for X2 in A:
# 4
# +
# 3
# +
# 3
# +
# 3
# =
# 13
# 4+3+3+3=13
#
# 𝑃
# (
# 𝑋
# 2
# =
# 4
# ∣
# 𝐴
# )
# =
# 3
# /
# 13
# ≈
# 0.2308
# P(X2=4∣A)=3/13≈0.2308
#
# 𝑃
# (
# 𝐴
# ∣
# 𝑋
# 1
# =
# 3
# ,
# 𝑋
# 2
# =
# 4
# )
# ∝
# 0.5
# ⋅
# 0.4
# ⋅
# 0.2308
# ≈
# 0.04616
# P(A∣X1=3,X2=4)∝0.5⋅0.4⋅0.2308≈0.04616
#
# For Class B:
#
# Total counts for X1 in B:
# 2
# +
# 2
# +
# 1
# =
# 5
# 2+2+1=5
#
# 𝑃
# (
# 𝑋
# 1
# =
# 3
# ∣
# 𝐵
# )
# =
# 1
# /
# 5
# =
# 0.2
# P(X1=3∣B)=1/5=0.2
#
# Total counts for X2 in B:
# 2
# +
# 2
# +
# 2
# +
# 3
# =
# 9
# 2+2+2+3=9
#
# 𝑃
# (
# 𝑋
# 2
# =
# 4
# ∣
# 𝐵
# )
# =
# 3
# /
# 9
# =
# 0.3333
# P(X2=4∣B)=3/9=0.3333
#
# 𝑃
# (
# 𝐵
# ∣
# 𝑋
# 1
# =
# 3
# ,
# 𝑋
# 2
# =
# 4
# )
# ∝
# 0.5
# ⋅
# 0.2
# ⋅
# 0.3333
# ≈
# 0.03333
# P(B∣X1=3,X2=4)∝0.5⋅0.2⋅0.3333≈0.03333
# Step 2: Compare posteriors
# 𝑃
# (
# 𝐴
# ∣
# 𝑋
# 1
# ,
# 𝑋
# 2
# )
# ≈
# 0.04616
# P(A∣X1,X2)≈0.04616
# 𝑃
# (
# 𝐵
# ∣
# 𝑋
# 1
# ,
# 𝑋
# 2
# )
# ≈
# 0.03333
# P(B∣X1,X2)≈0.03333
#
# ⇒
# ⇒ Naive Bayes predicts class A.
#
# ✅ Answer
#
# Predicted class: A
